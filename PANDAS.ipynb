# %%
import pandas as pd
file_path="C:/Users/DELL/Downloads/Student Mental health.csv"
data=pd.read_csv(file_path)
data
# Out:
#                Timestamp Choose your gender   Age What is your course?  \
# 0         8/7/2020 12:02             Female  18.0          Engineering
# 1         8/7/2020 12:04               Male  21.0    Islamic education
# 2         8/7/2020 12:05               Male  19.0                  BIT
# 3         8/7/2020 12:06             Female  22.0                 Laws
# 4         8/7/2020 12:13               Male  23.0         Mathemathics
# ..                   ...                ...   ...                  ...
# 96   13/07/2020 19:56:49             Female  21.0                  BCS
# 97   13/07/2020 21:21:42               Male  18.0          Engineering
# 98   13/07/2020 21:22:56             Female  19.0             Nursing
# 99   13/07/2020 21:23:57             Female  23.0     Pendidikan Islam
# 100  18/07/2020 20:16:21               Male  20.0   Biomedical science
#
#     Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
selected_columns=data[['Age','Marital status','What is your CGPA?']]
selected_columns
# Out:
#       Age Marital status What is your CGPA?
# 0    18.0             No        3.00 - 3.49
# 1    21.0             No        3.00 - 3.49
# 2    19.0             No        3.00 - 3.49
# 3    22.0            Yes        3.00 - 3.49
# 4    23.0             No        3.00 - 3.49
# ..    ...            ...                ...
# 96   21.0             No        3.50 - 4.00
# 97   18.0             No        3.00 - 3.49
# 98   19.0            Yes        3.50 - 4.00
# 99   23.0             No        3.50 - 4.00
# 100  20.0             No        3.00 - 3.49
#
# [101 rows x 3 columns]

# %%
filtered_data=data[data['Age']>20]
filtered_data
# Out:
#               Timestamp Choose your gender   Age     What is your course?  \
# 1        8/7/2020 12:04               Male  21.0        Islamic education
# 3        8/7/2020 12:06             Female  22.0                     Laws
# 4        8/7/2020 12:13               Male  23.0             Mathemathics
# 6        8/7/2020 12:32             Female  23.0         Pendidikan islam
# 11       8/7/2020 12:39             Female  24.0              Engineering
# 15       8/7/2020 12:43               Male  24.0                      BCS
# 16       8/7/2020 12:46             Female  24.0              Accounting
# 17       8/7/2020 12:52             Female  24.0                      ENM
# 22       8/7/2020 13:13             Female  24.0                      BCS
# 23       8/7/2020 13:15             Female  24.0              Engineering
# 24       8/7/2020 13:17             Female  23.0                      BCS
# 28       8/7/2020 13:58             Female  24.0                      BIT
# ...

# %%
data_sorted=data.sort_values(by='What is your CGPA?')
data_sorted
# Out:
#               Timestamp Choose your gender   Age What is your course?  \
# 94  13/07/2020 17:30:44             Female  24.0                 Fiqh
# 43       8/7/2020 15:07               Male   NaN                  BIT
# 73        9/7/2020 6:57               Male  18.0   Biomedical science
# 78  13/07/2020 10:07:32             Female  19.0        Biotechnology
# 35       8/7/2020 14:43             Female  18.0          Engineering
# ..                  ...                ...   ...                  ...
# 65       8/7/2020 17:50             Female  23.0                Econs
# 19       8/7/2020 13:07             Female  18.0       Marine science
# 26       8/7/2020 13:35             Female  19.0          Engineering
# 68       8/7/2020 19:05             Female  18.0               Malcom
# 6        8/7/2020 12:32             Female  23.0     Pendidikan islam
#
#    Your current year of Study What is your CGPA? Marital status  \
# ...

# %%
import pandas
mydataset={
    'cars':["BMW","Volvo","Ford"],
    'passings':[3,7,2]
}
myvar=pandas.DataFrame(mydataset)
print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
