# %%
import pandas as pd
data = {'Header 1': ['Data 1', 'Data 3'],
        'Header 2': ['Data 2', 'Data 4']}
df = pd.DataFrame(data)
print(df)
# Out:
#   Header 1 Header 2
# 0   Data 1   Data 2
# 1   Data 3   Data 4

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as mpimg
img=mpimg.imread("C:/Users/DELL/Pictures/CAFE-2.png")
plt.imshow(img)
plt.axis('on')
plt.show()

# %%
from datetime import datetime,timedelta
now=datetime.now()
print("current date and time",now)
formatted_date=now.strftime("%y-%m-%d %H:%M:%S")
print("formatted Date:",formatted_date)
new_date=now=timedelta(days=7)
print("Date after 7 days:",new_date)
# Out:
# current date and time 2024-01-15 15:36:30.275192
# formatted Date: 24-01-15 15:36:30
# Date after 7 days: 7 days, 0:00:00

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [24, 25, 36]}

df = pd.DataFrame(data)
young_people = df[df['Age'] < 30]

print("young_people:")
print(young_people)
# Out:
# young_people:
#     Name  Age
# 0  Alice   24
# 1    Bob   25

# %%
from datetime import datetime

date_string = '2022-01-15'
parsed_date = datetime.strptime(date_string, '%Y-%m-%d')
print(f"parsed Date: {parsed_date}")
# Out:
# parsed Date: 2022-01-15 00:00:00

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("C:/Users/DELL/Pictures/bird.jpeg")
plt.imshow(img)
plt.axis('off')  # Turn off axis labels
plt.title('Bird')
plt.xlabel('x-axis label')
plt.ylabel('y-axis label')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 5
#       2 import matplotlib.image as mpimg
#       4 # Load the images
# ----> 5 img1 = mpimg.imread("C:/Users/DELL/Pictures/bird1.jpeg")
#       6 img2 = mpimg.imread("C:/Users/DELL/Pictures/bird2.jpeg")
#       7 img3 = mpimg.imread("C:/Users/DELL/Pictures/bird3.jpeg")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\image.py:1563, in imread(fname, format)
#    1556 if isinstance(fname, str) and len(parse.urlparse(fname).scheme) > 1:
#    1557     # Pillow doesn't handle URLs directly.
#    1558     raise ValueError(
#    1559         "Please open the URL for reading and pass the "
#    1560         "result to Pillow, e.g. with "
#    1561         "``np.array(PIL.Image.open(urllib.request.urlopen(url)))``."
#    1562         )
# -> 1563 with img_open(fname) as image:
# ...
